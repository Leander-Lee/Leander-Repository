# %%
import requests
import time

results = []
for i in range(100):
    url = "https://api.wheretheiss.at/v1/satellites/25544"
    table = requests.get(url)
    if table.status_code == 200:
        data = table.json()
        timestamp = data["timestamp"]
        latitude = float(data["latitude"])
        longitude = float(data["longitude"])
        results.append((timestamp, latitude, longitude))
    else:
        Error = "Error"
        print(Error)
        break
    time.sleep(10)

print(results)
# Out:
# [(1751640447, 47.609718211712, 135.53154401833), (1751640458, 47.888096965272, 136.45629109563), (1751640470, 48.182316097019, 137.47682744071), (1751640481, 48.443160898497, 138.42293820657), (1751640493, 48.717861464999, 139.46648573082), (1751640505, 48.982069765069, 140.52175030266), (1751640516, 49.214867890419, 141.49917576792), (1751640527, 49.438517577732, 142.48604440295), (1751640539, 49.671885375862, 143.57313847927), (1751640551, 49.893986471177, 144.67087921261), (1751640562, 50.087517812169, 145.68618621166), (1751640573, 50.271278681016, 146.70983942803), (1751640585, 50.460440299895, 147.83569486584), (1751640596, 50.623332252389, 148.87573480073), (1751640608, 50.789416982899, 150.01860561243), (1751640620, 50.943230329457, 151.16963171784), (1751640632, 51.084623928146, 152.32826715319), (1751640643, 51.203207657339, 153.39655843428), (1751640654, 51.311141561647, 154.47031098135), (1751640665, 51.408336065127, 155.54905860363), (1751640677, 51.502020986513, 156.7309850268), (1751640689, 51.582732093383, 157.91761383103), (1751640700, 51.64524898631, 159.00890760051), (1751640711, 51.696739909458, 160.10304385504), (1751640722, 51.737160336578, 161.19948736824), (1751640734, 51.768587836327, 162.39758165382), (1751640746, 51.786765694766, 163.59704070568), (1751640759, 51.791484750866, 164.89714302898), (1751640770, 51.783310359668, 165.99711504049), (1751640781, 51.763989779034, 167.09639052134), (1751640793, 51.730221285057, 168.29413687267), (1751640805, 51.683244170528, 169.48966290474), (1751640816, 51.628620527092, 170.58299502835), (1751640827, 51.562986986803, 171.67332216779), (1751640839, 51.478897952377, 172.85871109398), (1751640851, 51.381860749074, 174.03922115862), (1751640863, 51.271974378523, 175.21419669981), (1751640874, 51.160052191197, 176.28585424947), (1751640886, 51.025857151686, 177.44848261201), (1751640897, 50.891865244687, 178.50782122699), (1751640909, 50.733845396791, 179.6559666627), (1751640921, 50.563611522488, -179.20423096303), (1751640932, 50.396969368827, -178.16715871029), (1751640945, 50.187146540938, -176.9515943346), (1751640958, 49.963580600529, -175.74746235105), (1751640969, 49.763845920641, -174.73788332508), (1751640981, 49.535092795493, -173.64661235865), (1751640994, 49.274705923597, -172.47665261938), (1751641006, 49.022958904371, -171.40832640091), (1751641018, 48.760487979495, -170.35145476707), (1751641030, 48.487498679987, -169.30627037459), (1751641041, 48.228198416094, -168.35863319606), (1751641053, 47.935640832248, -167.33641821715), (1751641064, 47.65876089084, -166.41011365004), (1751641076, 47.347419536542, -165.41142544272), (1751641089, 46.999434168418, -164.34354203246), (1751641100, 46.696492495772, -163.45141270955), (1751641112, 46.357340414666, -162.49021754786), (1751641124, 46.009347448123, -161.54159981698), (1751641137, 45.622627710012, -160.52813165636), (1751641149, 45.256904587426, -159.60571395859), (1751641160, 44.914460918687, -158.77116624017), (1751641172, 44.533231195117, -157.87270782594), (1751641184, 44.144211160931, -156.98664956207), (1751641196, 43.74760672543, -156.11290979157), (1751641207, 43.37755861098, -155.32271048101), (1751641219, 42.966971201703, -154.4722761111), (1751641231, 42.54937546184, -153.63382649883), (1751641243, 42.124959728563, -152.8072185628), (1751641255, 41.693914527885, -151.99231038969), (1751641266, 41.293120438264, -151.25545033489), (1751641279, 40.812661354808, -150.39694593485), (1751641291, 40.362813620897, -149.61615901321), (1751641303, 39.907047930572, -148.84639630554), (1751641315, 39.445536623482, -148.08747978346), (1751641327, 38.978442104574, -147.33921651102), (1751641339, 38.5059276249, -146.60141725828), (1751641352, 37.988105630015, -145.81371959373), (1751641364, 37.504802486729, -145.09709071845), (1751641377, 36.975648647235, -144.33185752577), (1751641388, 36.523509233077, -143.69319763974), (1751641400, 36.025806742048, -143.0055269702), (1751641413, 35.481536812805, -142. ...

# %%
#Could have already been done earlier in the code for better viewing but I preferred not to stop half way and just filter it

import matplotlib.pyplot as plt

time = [i[0] for i in results]
lat = [i[1] for i in results]
long = [i[2] for i in results]

#x-axis: longitude
#y-axis: latitude
plt.plot(long, lat, )

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Longitude vs Latitude")

plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

time = [i[0] for i in results]
lat = [i[1] for i in results]
long = [i[2] for i in results]

#x-axis: longitude
#y-axis: latitude
plt.plot(time, lat)

plt.xlabel("Time")
plt.ylabel("Latitude")
plt.title("Time vs Latitude")

plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

time = [i[0] for i in results]
lat = [i[1] for i in results]
long = [i[2] for i in results]

#x-axis: longitude
#y-axis: latitude
plt.plot(time, long)

plt.xlabel("Time")
plt.ylabel("Longitude")
plt.title("Time vs Longitude")

plt.grid(True)

plt.show()

# %%
#a more accurate depiction of the real-time location of the iss in ~19 minutes
import matplotlib.pyplot as plt

time = [i[0] for i in results]
lat = [i[1] for i in results]
long = [i[2] for i in results]

#x-axis: longitude
#y-axis: latitude
plt.figure(figsize=(12, 6))
plt.plot(long, lat)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Time vs Longitude")
plt.xlim(-180, 180)
plt.ylim(-90, 90)  
plt.grid(True)

plt.show()
